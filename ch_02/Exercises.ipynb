# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data/parsed.csv')

# %%
df.head()
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3   NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4   NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt    gap           ids   mag magType  ...     status  \
# 0  0.008693   NaN   85.0  ,ci37389218,  1.35      ml  ...  automatic
# 1  0.020030   NaN   79.0  ,ci37389202,  1.29      ml  ...  automatic
# 2  0.021370  28.0   21.0  ,ci37389194,  3.42      ml  ...  automatic
# 3  0.026180   NaN   39.0  ,ci37389186,  0.44      ml  ...  automatic
# 4  0.077990   NaN  192.0  ,nc73096941,  2.16      md  ...  automatic
#
#             time                          title tsunami        type  \
# ...

# %%
df.loc[df.mag > 7.0]
# Out:
#      alert  cdi      code                                             detail  \
# 5263   red  8.4  1000h3p4  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt   gap                      ids  mag magType  ...    status  \
# 5263  1.589  18.0  27.0  ,us1000h3p4,us1000h4p4,  7.5     mww  ...  reviewed
#
#                time                              title tsunami        type  \
# 5263  1538128963480  M 7.5 - 78km N of Palu, Indonesia       1  earthquake
#
#                                                   types     tz        updated  \
# 5263  ,dyfi,finite-fault,general-text,geoserve,groun...  480.0  1539123134531
#
#                                                     url parsed_place
# 5263  https://earthquake.usgs.gov/earthquakes/eventp...    Indonesia
#
# [1 rows x 27 columns]

# %%
df.describe(percentiles=[0.05,0.95],include='all')
# Out:
#         alert         cdi      code  \
# count      59  329.000000      9332
# unique      2         NaN      9332
# top     green         NaN  20261467
# freq       58         NaN         1
# mean      NaN    2.754711       NaN
# std       NaN    1.010637       NaN
# min       NaN    0.000000       NaN
# 5%        NaN    2.000000       NaN
# 50%       NaN    2.700000       NaN
# 95%       NaN    4.300000       NaN
# max       NaN    8.400000       NaN
#
#                                                    detail         dmin  \
# count                                                9332  6139.000000
# unique                                               9332          NaN
# top     https://earthquake.usgs.gov/fdsnws/event/1/que...          NaN
# freq                                                    1          NaN
# mean                                                  NaN     0.544925
# std                                                   NaN     2.214305
# ...

# %%
df.loc[(df.magType == "mb") & (df.parsed_place.str.contains("Japan")),["parsed_place","magType",'tsunami']]
# Out:
#      parsed_place magType  tsunami
# 67          Japan      mb        0
# 713         Japan      mb        0
# 1124        Japan      mb        0
# 1309        Japan      mb        0
# 1398        Japan      mb        0
# 1422        Japan      mb        0
# 1435        Japan      mb        0
# 1492        Japan      mb        0
# 1563        Japan      mb        0
# 1732        Japan      mb        0
# 1875        Japan      mb        0
# 1898        Japan      mb        0
# 2053        Japan      mb        0
# 2191        Japan      mb        0
# 2564        Japan      mb        0
# 2576        Japan      mb        0
# 2688        Japan      mb        0
# 2824        Japan      mb        0
# 3072        Japan      mb        0
# 3632        Japan      mb        0
# 3771        Japan      mb        0
# 3851        Japan      mb        0
# 4082        Japan      mb        0
# 4192        Japan      mb        0
# 4257        Japan      mb        0
# 4846        Japan      mb        0
# ...

# %%
df.columns
# Out:
# Index(['alert', 'cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag',
#        'magType', 'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources',
#        'status', 'time', 'title', 'tsunami', 'type', 'types', 'tz', 'updated',
#        'url', 'parsed_place'],
#       dtype='object')

# %%
t = len(df.loc[(df.parsed_place.str.contains("Indo")) & (df.tsunami > 0),['alert','mag','tsunami']])
nt = len(df.loc[(df.parsed_place.str.contains("Indo")) & (df.tsunami > 0),['alert','mag','tsunami']])
t/(t+nt)
# Out:
# 0.5

# %%
df.loc[df.parsed_place.str.contains('Nevada')].describe()
# Out:
#              cdi        dmin       felt         gap         mag   mmi  \
# count  15.000000  681.000000  15.000000  681.000000  681.000000  1.00
# mean    2.440000    0.166199   2.400000  153.668120    0.500073  2.84
# std     0.501142    0.166228   4.626013   68.735302    0.696710   NaN
# min     2.000000    0.001000   1.000000   29.140000   -0.500000  2.84
# 25%     2.000000    0.053000   1.000000   97.380000   -0.100000  2.84
# 50%     2.200000    0.112000   1.000000  149.140000    0.400000  2.84
# 75%     2.900000    0.233000   1.000000  199.720000    0.900000  2.84
# max     3.300000    1.414000  19.000000  355.910000    2.900000  2.84
#
#               nst         rms         sig          time  tsunami     tz  \
# count  681.000000  681.000000  681.000000  6.810000e+02    681.0  681.0
# mean    12.618209    0.151986   10.970631  1.538314e+12      0.0 -480.0
# std      9.866963    0.084662   19.607150  5.965637e+08      0.0    0.0
# ...
